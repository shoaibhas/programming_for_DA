# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv('../data/data-selected-columns.csv', index_col=1)

# Head of the df

print(df.head())
# Out:
#                           date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# price
# 313000.0   2014-05-02 00:00:00       3.0       1.50         1340      7912
# 2384000.0  2014-05-02 00:00:00       5.0       2.50         3650      9050
# 342000.0   2014-05-02 00:00:00       3.0       2.00         1930     11947
# 420000.0   2014-05-02 00:00:00       3.0       2.25         2000      8030
# 550000.0   2014-05-02 00:00:00       4.0       2.50         1940     10500
#
#            floors  waterfront  view  condition
# price
# 313000.0      1.5           0     0          3
# 2384000.0     2.0           0     4          5
# 342000.0      1.0           0     0          4
# 420000.0      1.0           0     0          4
# 550000.0      1.0           0     0          4
